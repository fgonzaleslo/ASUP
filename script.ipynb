-- %% [markdown]
-- # [dbo].[GDI_ASUP_CICLO_ACADEMICO]

-- %%
USE [ASUP_BD_TEST]
GO

-- %%
/****** Object:  Table [dbo].[GDI_ASUP_CICLO_ACADEMICO]    Script Date: 15/07/2022 22:52:52 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[GDI_ASUP_CICLO_ACADEMICO](
	[id_ciclo_academico] [int] NOT NULL,
	[ciclo] [varchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[id_ciclo_academico] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[GDI_ASUP_CURSO]

-- %%
/****** Object:  Table [dbo].[GDI_ASUP_CURSO]    Script Date: 15/07/2022 22:52:52 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[GDI_ASUP_CURSO](
	[id_curso] [nvarchar](10) NOT NULL,
	[nombre_curso] [varchar](255) NULL,
	[horario_curso] [varchar](255) NULL,
	[id_docente] [nvarchar](10) NULL,
PRIMARY KEY CLUSTERED 
(
	[id_curso] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[GDI_ASUP_DOCENTE]

-- %%
/****** Object:  Table [dbo].[GDI_ASUP_DOCENTE]    Script Date: 15/07/2022 22:52:52 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[GDI_ASUP_DOCENTE](
	[id_docente] [int] NOT NULL,
	[nombres_docente] [nvarchar](255) NULL,
	[apellidos_docente] [nvarchar](255) NULL,
	[direccion_docente] [nvarchar](255) NULL,
	[sexo_docente] [nvarchar](50) NULL,
	[fecha_nac_docente] [datetime] NULL,
	[contacto_docente] [nvarchar](255) NULL,
 CONSTRAINT [PK_GDI_ASUP_DOCENTE] PRIMARY KEY CLUSTERED 
(
	[id_docente] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[GDI_ASUP_DOCENTE_TEST]

-- %%
/****** Object:  Table [dbo].[GDI_ASUP_DOCENTE_TEST]    Script Date: 15/07/2022 22:52:52 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[GDI_ASUP_DOCENTE_TEST](
	[id_docente] [nvarchar](10) NOT NULL,
	[nombre_docente] [varchar](255) NULL,
	[apellido_docente] [varchar](255) NULL,
	[direccion_docente] [varchar](255) NULL,
	[sexo_docente] [varchar](255) NULL,
	[fecha_nac_docente] [datetime] NULL,
	[contacto_docente] [varchar](255) NULL,
PRIMARY KEY CLUSTERED 
(
	[id_docente] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[GDI_ASUP_ESTUDIANTE]

-- %%
/****** Object:  Table [dbo].[GDI_ASUP_ESTUDIANTE]    Script Date: 15/07/2022 22:52:52 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[GDI_ASUP_ESTUDIANTE](
	[id_estudiante] [int] NULL,
	[nombres_estudiante] [varchar](255) NULL,
	[apellidos_estudiante] [varchar](255) NULL,
	[direccion_estudiante] [varchar](255) NULL,
	[sexo_estudiante] [varchar](255) NULL,
	[fecha_nac_estudiante] [varchar](255) NULL,
	[contacto_estudiante] [nvarchar](9) NULL,
	[id_ciclo_academico] [int] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[GDI_ASUP_MATRICULA]

-- %%
/****** Object:  Table [dbo].[GDI_ASUP_MATRICULA]    Script Date: 15/07/2022 22:52:52 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[GDI_ASUP_MATRICULA](
	[id_matricula] [nvarchar](10) NOT NULL,
	[responsable_matricula] [varchar](255) NOT NULL,
	[fecha_matricula] [datetime] NOT NULL,
	[modalidad] [varchar](255) NOT NULL,
	[id_ciclo_academico] [int] NOT NULL,
	[id_curso] [nvarchar](10) NOT NULL,
	[id_docente] [nvarchar](10) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[id_matricula] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[GDI_ASUP_PRUEBA]

-- %%
/****** Object:  Table [dbo].[GDI_ASUP_PRUEBA]    Script Date: 15/07/2022 22:52:52 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[GDI_ASUP_PRUEBA](
	[id_prueba] [int] NOT NULL,
	[prueba] [varchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[id_prueba] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[GDI_ASUP_PRUEBA2]

-- %%
/****** Object:  Table [dbo].[GDI_ASUP_PRUEBA2]    Script Date: 15/07/2022 22:52:52 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[GDI_ASUP_PRUEBA2](
	[id_prueba2] [int] NULL,
	[nombres_prueba] [varchar](255) NULL,
	[apellidos_prueba] [varchar](255) NULL,
	[id_prueba] [int] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK_GDI_ASUP_DOCENTE_GDI_ASUP_DOCENTE]

-- %%
ALTER TABLE [dbo].[GDI_ASUP_DOCENTE]  WITH CHECK ADD  CONSTRAINT [FK_GDI_ASUP_DOCENTE_GDI_ASUP_DOCENTE] FOREIGN KEY([id_docente])
REFERENCES [dbo].[GDI_ASUP_DOCENTE] ([id_docente])
GO
ALTER TABLE [dbo].[GDI_ASUP_DOCENTE] CHECK CONSTRAINT [FK_GDI_ASUP_DOCENTE_GDI_ASUP_DOCENTE]
GO

-- %% [markdown]
-- # [FK__GDI_ASUP___id_ci__5CD6CB2B]

-- %%
ALTER TABLE [dbo].[GDI_ASUP_ESTUDIANTE]  WITH CHECK ADD FOREIGN KEY([id_ciclo_academico])
REFERENCES [dbo].[GDI_ASUP_CICLO_ACADEMICO] ([id_ciclo_academico])
GO

-- %% [markdown]
-- # [fk_ciclo]

-- %%
ALTER TABLE [dbo].[GDI_ASUP_MATRICULA]  WITH CHECK ADD  CONSTRAINT [fk_ciclo] FOREIGN KEY([id_ciclo_academico])
REFERENCES [dbo].[GDI_ASUP_CICLO_ACADEMICO] ([id_ciclo_academico])
GO
ALTER TABLE [dbo].[GDI_ASUP_MATRICULA] CHECK CONSTRAINT [fk_ciclo]
GO

-- %% [markdown]
-- # [fk_curso]

-- %%
ALTER TABLE [dbo].[GDI_ASUP_MATRICULA]  WITH CHECK ADD  CONSTRAINT [fk_curso] FOREIGN KEY([id_curso])
REFERENCES [dbo].[GDI_ASUP_CURSO] ([id_curso])
GO
ALTER TABLE [dbo].[GDI_ASUP_MATRICULA] CHECK CONSTRAINT [fk_curso]
GO

-- %% [markdown]
-- # [fk_docente]

-- %%
ALTER TABLE [dbo].[GDI_ASUP_MATRICULA]  WITH CHECK ADD  CONSTRAINT [fk_docente] FOREIGN KEY([id_docente])
REFERENCES [dbo].[GDI_ASUP_DOCENTE_TEST] ([id_docente])
GO
ALTER TABLE [dbo].[GDI_ASUP_MATRICULA] CHECK CONSTRAINT [fk_docente]
GO

-- %% [markdown]
-- # [FK__GDI_ASUP___id_pr__6477ECF3]

-- %%
ALTER TABLE [dbo].[GDI_ASUP_PRUEBA2]  WITH CHECK ADD FOREIGN KEY([id_prueba])
REFERENCES [dbo].[GDI_ASUP_PRUEBA] ([id_prueba])
GO

-- %% [markdown]
-- # [dbo].[cargar_docente]

-- %%
/****** Object:  StoredProcedure [dbo].[cargar_docente]    Script Date: 15/07/2022 22:52:52 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create procedure [dbo].[cargar_docente]
as
select id_docente,CONCAT_WS(' ',nombres_docente,apellidos_docente) AS 'Nombre completo' from GDI_ASUP_DOCENTE
GO

-- %% [markdown]
-- # [dbo].[Editar_docente_ASUP]

-- %%
/****** Object:  StoredProcedure [dbo].[Editar_docente_ASUP]    Script Date: 15/07/2022 22:52:52 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[Editar_docente_ASUP]
@DocenteID int,
@DocenteNombre nvarchar(255),
@DocenteApellido nvarchar(255),
@DocenteDireccion nvarchar(255),
@DocenteSexo nvarchar(50),
@DocenteFechaNac datetime,
@DocenteContacto nvarchar(255)
as
begin
Update GDI_ASUP_DOCENTE set nombres_docente= @DocenteNombre,apellidos_docente =@DocenteApellido,
direccion_docente= @DocenteDireccion,sexo_docente= @DocenteSexo,fecha_nac_docente= @DocenteFechaNac,contacto_docente= @DocenteContacto WHERE id_docente= @DocenteID
end
GO

-- %% [markdown]
-- # [dbo].[Editar_docente_ASUP_test]

-- %%
/****** Object:  StoredProcedure [dbo].[Editar_docente_ASUP_test]    Script Date: 15/07/2022 22:52:52 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[Editar_docente_ASUP_test]
@DocenteID nvarchar(10),
@DocenteNombre varchar(255),
@DocenteApellido varchar(255),
@DocenteDireccion varchar(255),
@DocenteSexo varchar(255),
@DocenteFechaNac datetime,
@DocenteContacto varchar(255)
as
begin
update GDI_ASUP_DOCENTE_TEST set
nombre_docente= @DocenteNombre,
apellido_docente= @DocenteApellido,
direccion_docente= @DocenteDireccion,
sexo_docente= @DocenteSexo,
fecha_nac_docente= @DocenteFechaNac,
contacto_docente= @DocenteContacto where id_docente= @DocenteID 
end
GO

-- %% [markdown]
-- # [dbo].[Eliminar_docente_ASUP]

-- %%
/****** Object:  StoredProcedure [dbo].[Eliminar_docente_ASUP]    Script Date: 15/07/2022 22:52:52 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[Eliminar_docente_ASUP]
@DocenteID int
as
begin
DELETE GDI_ASUP_DOCENTE WHERE id_docente= @DocenteID
end
GO

-- %% [markdown]
-- # [dbo].[Eliminar_docente_ASUP_test]

-- %%
/****** Object:  StoredProcedure [dbo].[Eliminar_docente_ASUP_test]    Script Date: 15/07/2022 22:52:52 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[Eliminar_docente_ASUP_test]
@DocenteID nvarchar(10)
as
begin
DELETE GDI_ASUP_DOCENTE_TEST WHERE id_docente= @DocenteID
end
GO

-- %% [markdown]
-- # [dbo].[Eliminar_estudiante_ASUP]

-- %%
/****** Object:  StoredProcedure [dbo].[Eliminar_estudiante_ASUP]    Script Date: 15/07/2022 22:52:52 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[Eliminar_estudiante_ASUP]
@EstudianteID int
as
begin
DELETE GDI_ASUP_ESTUDIANTE WHERE id_estudiante=@EstudianteID 
end
GO

-- %% [markdown]
-- # [dbo].[Insertar_curso_ASUP]

-- %%
/****** Object:  StoredProcedure [dbo].[Insertar_curso_ASUP]    Script Date: 15/07/2022 22:52:52 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[Insertar_curso_ASUP]
@IDCURSO nvarchar(10),
@NOMBRECURSO varchar(255),
@HORARIOCURSO varchar(255),
@IDDOCENTE nvarchar(10)
as
begin
Insert into GDI_ASUP_CURSO(id_curso,nombre_curso,horario_curso,id_docente)
VALUES (@IDCURSO,@NOMBRECURSO,@HORARIOCURSO,@IDDOCENTE)
END
GO

-- %% [markdown]
-- # [dbo].[Insertar_docente_ASUP]

-- %%
/****** Object:  StoredProcedure [dbo].[Insertar_docente_ASUP]    Script Date: 15/07/2022 22:52:52 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[Insertar_docente_ASUP]
@DocenteID int,
@DocenteNombre nvarchar(255),
@DocenteApellido nvarchar(255),
@DocenteDireccion nvarchar(255),
@DocenteSexo nvarchar(50),
@DocenteFechaNac datetime,
@DocenteContacto nvarchar(255)
as
begin
Insert into GDI_ASUP_DOCENTE (id_docente,nombres_docente,apellidos_docente,
direccion_docente,sexo_docente,fecha_nac_docente,contacto_docente) VALUES (@DocenteID,@DocenteNombre,
@DocenteApellido,@DocenteDireccion,@DocenteSexo,@DocenteFechaNac,@DocenteContacto)
end
GO

-- %% [markdown]
-- # [dbo].[Insertar_docente_ASUP_test]

-- %%
/****** Object:  StoredProcedure [dbo].[Insertar_docente_ASUP_test]    Script Date: 15/07/2022 22:52:52 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[Insertar_docente_ASUP_test]
@DocenteID nvarchar(10),
@DocenteNombre varchar(255),
@DocenteApellido varchar(255),
@DocenteDireccion varchar(255),
@DocenteSexo varchar(255),
@DocenteFechaNac datetime,
@DocenteContacto varchar(255)
as
begin
Insert into GDI_ASUP_DOCENTE_TEST (id_docente,
nombre_docente,
apellido_docente,
direccion_docente,
sexo_docente,
fecha_nac_docente,
contacto_docente) 
VALUES (@DocenteID,
@DocenteNombre,
@DocenteApellido,
@DocenteDireccion,
@DocenteSexo,
@DocenteFechaNac,
@DocenteContacto)
end
GO

-- %% [markdown]
-- # [dbo].[Insertar_estudiante_ASUP]

-- %%
/****** Object:  StoredProcedure [dbo].[Insertar_estudiante_ASUP]    Script Date: 15/07/2022 22:52:52 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[Insertar_estudiante_ASUP]
@EstudianteID int,
@EstudianteNombre varchar(255),
@EstudianteApellido varchar(255),
@EstudianteDireccion varchar(255),
@EstudianteSexo varchar(255),
@EstudianteFechaNac varchar(255),
@EstudianteContacto nvarchar(9),
@EstudianteCicloAcademicoID int
as
begin
Insert into GDI_ASUP_ESTUDIANTE(id_estudiante,nombres_estudiante,apellidos_estudiante,direccion_estudiante,
sexo_estudiante,fecha_nac_estudiante,contacto_estudiante,id_ciclo_academico) 
VALUES (@EstudianteID,
@EstudianteNombre,
@EstudianteApellido,
@EstudianteDireccion,
@EstudianteSexo,
@EstudianteFechaNac,
@EstudianteContacto,
@EstudianteCicloAcademicoID)
end
GO

-- %% [markdown]
-- # [dbo].[Insertar_matricula_ASUP]

-- %%
/****** Object:  StoredProcedure [dbo].[Insertar_matricula_ASUP]    Script Date: 15/07/2022 22:52:52 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[Insertar_matricula_ASUP] 
@MatriculaID nvarchar(10),
@MatriculaResponsable varchar(255),
@MatriculaFecha datetime,
@MatriculaModalidad varchar(255),
@CicloAcademicoID int,
@CursoID nvarchar(10),
@DocenteID nvarchar(10)
as
begin
insert into GDI_ASUP_MATRICULA (id_matricula,responsable_matricula,fecha_matricula,modalidad,id_ciclo_academico,id_curso,id_docente)
values (@MatriculaID,@MatriculaResponsable,@MatriculaFecha,@MatriculaModalidad,@CicloAcademicoID,@CursoID,@DocenteID)
END
GO

-- %% [markdown]
-- # [dbo].[Insertar_prueba_ASUP]

-- %%
/****** Object:  StoredProcedure [dbo].[Insertar_prueba_ASUP]    Script Date: 15/07/2022 22:52:52 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[Insertar_prueba_ASUP]
@PruebaID int,
@PruebaNombre varchar(255),
@PruebaApellido varchar(255),
@Purbea2ID int
as
begin
Insert into GDI_ASUP_PRUEBA2 (id_prueba2,
nombres_prueba,
apellidos_prueba,
id_prueba) 
VALUES (@PruebaID,
@PruebaNombre,
@PruebaApellido,
@Purbea2ID )
end
GO

-- %% [markdown]
-- # [dbo].[Lista_curso_ASUP]

-- %%
/****** Object:  StoredProcedure [dbo].[Lista_curso_ASUP]    Script Date: 15/07/2022 22:52:52 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[Lista_curso_ASUP]
as
begin
select c.id_curso, c.nombre_curso, c.horario_curso, c.id_docente, d.nombre_docente, d.apellido_docente from dbo.GDI_ASUP_CURSO c
INNER JOIN dbo.GDI_ASUP_DOCENTE_TEST d 
ON
c.id_docente = d.id_docente
END
GO

-- %% [markdown]
-- # [dbo].[Lista_curso_matricula]

-- %%
/****** Object:  StoredProcedure [dbo].[Lista_curso_matricula]    Script Date: 15/07/2022 22:52:52 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[Lista_curso_matricula]
as
begin
SELECT id_curso,nombre_curso FROM GDI_ASUP_CURSO
end
GO

-- %% [markdown]
-- # [dbo].[Lista_docente_ASUP]

-- %%
/****** Object:  StoredProcedure [dbo].[Lista_docente_ASUP]    Script Date: 15/07/2022 22:52:52 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[Lista_docente_ASUP]
as
begin
select * from GDI_ASUP_DOCENTE
end
GO

-- %% [markdown]
-- # [dbo].[Lista_docente_ASUP_test]

-- %%
/****** Object:  StoredProcedure [dbo].[Lista_docente_ASUP_test]    Script Date: 15/07/2022 22:52:52 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[Lista_docente_ASUP_test]
AS
BEGIN
select * from GDI_ASUP_DOCENTE_TEST
end
GO

-- %% [markdown]
-- # [dbo].[Lista_docente_matricula]

-- %%
/****** Object:  StoredProcedure [dbo].[Lista_docente_matricula]    Script Date: 15/07/2022 22:52:52 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[Lista_docente_matricula]
as
begin
select id_docente, CONCAT_WS(' ',nombre_docente,apellido_docente) as docente from GDI_ASUP_DOCENTE_TEST
end
GO

-- %% [markdown]
-- # [dbo].[Lista_estudiante_ASUP]

-- %%
/****** Object:  StoredProcedure [dbo].[Lista_estudiante_ASUP]    Script Date: 15/07/2022 22:52:52 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[Lista_estudiante_ASUP]
as
begin
select * from GDI_ASUP_ESTUDIANTE
end
GO

-- %% [markdown]
-- # [dbo].[Lista_estudiante_matricula]

-- %%
/****** Object:  StoredProcedure [dbo].[Lista_estudiante_matricula]    Script Date: 15/07/2022 22:52:52 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[Lista_estudiante_matricula]
as
begin
select id_estudiante, CONCAT_WS(' ',nombres_estudiante,apellidos_estudiante) as docente from GDI_ASUP_ESTUDIANTE
end
GO

-- %% [markdown]
-- # [dbo].[Lista_matricula_ASUP]

-- %%
/****** Object:  StoredProcedure [dbo].[Lista_matricula_ASUP]    Script Date: 15/07/2022 22:52:52 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[Lista_matricula_ASUP]
as
begin
SELECT m.id_matricula,m.responsable_matricula,m.fecha_matricula,m.modalidad,ac.ciclo,c.nombre_curso, CONCAT_WS(' ',d.nombre_docente,d.apellido_docente) as docente FROM dbo.GDI_ASUP_MATRICULA m
INNER JOIN dbo.GDI_ASUP_CICLO_ACADEMICO ac
ON ac.id_ciclo_academico=m.id_ciclo_academico
INNER JOIN dbo.GDI_ASUP_CURSO c
ON c.id_curso=m.id_curso
INNER JOIN dbo.GDI_ASUP_DOCENTE_TEST d
ON c.id_docente=d.id_docente
end
GO

-- %% [markdown]
-- # [dbo].[Lista_prueba_ASUP]

-- %%
/****** Object:  StoredProcedure [dbo].[Lista_prueba_ASUP]    Script Date: 15/07/2022 22:52:52 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[Lista_prueba_ASUP]
as
begin
SELECT a.id_prueba2,a.nombres_prueba,a.apellidos_prueba,a.id_prueba,b.prueba FROM GDI_ASUP_PRUEBA2 a
INNER JOIN GDI_ASUP_PRUEBA b ON
a.id_prueba = b.id_prueba 
end
GO

-- %% [markdown]
-- # [dbo].[Modificar_estudiante_ASUP]

-- %%
/****** Object:  StoredProcedure [dbo].[Modificar_estudiante_ASUP]    Script Date: 15/07/2022 22:52:52 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[Modificar_estudiante_ASUP]
@EstudianteID int,
@EstudianteNombre varchar(255),
@EstudianteApellido varchar(255),
@EstudianteDireccion varchar(255),
@EstudianteSexo varchar(255),
@EstudianteFechaNac varchar(255),
@EstudianteContacto nvarchar(9),
@EstudianteCicloAcademicoID int
as
begin
update GDI_ASUP_ESTUDIANTE set nombres_estudiante= @EstudianteNombre,apellidos_estudiante= @EstudianteApellido,
direccion_estudiante= @EstudianteDireccion,
sexo_estudiante= @EstudianteSexo,fecha_nac_estudiante= @EstudianteFechaNac,contacto_estudiante= @EstudianteContacto,
id_ciclo_academico= @EstudianteCicloAcademicoID where id_estudiante= @EstudianteID 
end
GO
